# %% [markdown]
# <a href="https://colab.research.google.com/github/Phani4584/Week_1-Python_lab1/blob/main/python5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#string methods
#1.split
#2.join
#3.strip
#4.upper and lower
#5.replace
#6.find
#7.count

# %%
a=str(input())
b=a.split()

print(b)
# Out:
# hello world is here
# ['hello', 'world', 'is', 'here']

# %%
a=str(input())
b=a.upper()
print(b)
# Out:
# hello
# HELLO

# %%
a=str(input())
print(a.lower())
# Out:
# PHANI
# phani

# %%
a='hello word'
b=a.replace('word','world')
print(b)
# Out:
# hello world

# %%
a=str(input("enter a string:" ))
b=a.lower()
vowels='a,e,i,o,u'
print("vowels:",v)
count_v=0
count_c=0
for ch in b:
  if ch.isalpha():
    if ch in vowels:
      count_v+1
    else:
      count_c+1
print("no of vowels=",count_v)
print("no of consonants=",count_c)
# Out:
# enter a string:phani
# vowels: a,e,i,o,u
# no of vowels= 0
# no of consonants= 0
