# %% [markdown]
# <a href="https://colab.research.google.com/github/Phani4584/Week_1-Python_lab1/blob/main/python_prog1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# python

# %%
print("good afternoon")
# Out:
# good afternoon

# %%
print(1+1)
# Out:
# 2

# %%
a=5
print(type(a))
# Out:
# <class 'int'>

# %%
a
# Out:
# 5

# %%
b=2.65

# %%
b
# Out:
# 2.65

# %%
a=input()
# Out:
# hi

# %%
a
# Out:
# 'hi'

# %%
a=input()
# Out:
# 3

# %%
a=int(input())
# Out:
# 5

# %%
a
# Out:
# 5

# %%
a=int(input())
# Out:
# phani
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1254/2310251140.py in <cell line: 0>()
# ----> 1 a=int(input())
#
# ValueError: invalid literal for int() with base 10: 'phani'

# %%
a=str(input())
b=int(input())
c=float(input())
d=int(input())
e=float(input())
f=(input())
g=(input())
print("a bought b apples for c rupees and d bananas for e rupees.finally a has f fruits which costed him g rupees")
# Out:
# phani
# 4
# 96.4
# 6
# 57.3
# b+d
# c+e
# a bought b apples for c rupees and d bananas for e rupees.finally a has f fruits which costed him g rupees

# %%
print('"a" bought "b" apples for "c" rupees and "d" bananas for "e" rupees.finally "a" has "f" fruits which costed him "g" rupees')
# Out:
# "a" bought "b" apples for "c" rupees and "d" bananas for "e" rupees.finally "a" has "f" fruits which costed him "g" rupees

# %%
a=(input())
b=(input())
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a//b)
print(a%b)
print(a**b)
# Out:
# 2
# 3
# 23
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1254/3388727529.py in <cell line: 0>()
#       2 b=(input())
#       3 print(a+b)
# ----> 4 print(a-b)
#       5 print(a*b)
#       6 print(a/b)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'
